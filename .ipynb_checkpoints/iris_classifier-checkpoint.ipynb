# %% [markdown]
# # The Iris Classification

# %% [markdown]
# ## Load the dataset

# %%
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
iris = datasets.load_iris()

# %% [markdown]
# ## DataFrame Conversion

# %%
import matplotlib.pyplot as plt
x = iris.data
y = iris.target
z = iris.target_names
target_names_df = pd.DataFrame(
    z,
    columns=["target name"]
)
target_names_df
# Out:
#   target name
# 0      setosa
# 1  versicolor
# 2   virginica

# %% [markdown]
# <img src="iris.png" />

# %%
feature_df = pd.DataFrame(
    x,
    columns=["sepal_length", "sepal_width", "petal_length", "petal_width"]
)

feature_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
target_df = pd.DataFrame(
    y,
    columns=["target"]
)
target_df
# Out:
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 1 columns]

# %%
final_df = pd.concat([feature_df, target_df], axis=1)
final_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Setosa

# %%
setosa_df = final_df[final_df["target"] == 0]
setosa_df.loc[:, 'iris_type'] = "setosa"
setosa_df[:5]
# Out:
# /tmp/ipykernel_3926/1300041551.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   setosa_df.loc[:, 'iris_type'] = "setosa"
#    sepal_length  sepal_width  petal_length  petal_width  target iris_type
# 0           5.1          3.5           1.4          0.2       0    setosa
# 1           4.9          3.0           1.4          0.2       0    setosa
# 2           4.7          3.2           1.3          0.2       0    setosa
# 3           4.6          3.1           1.5          0.2       0    setosa
# 4           5.0          3.6           1.4          0.2       0    setosa

# %% [markdown]
# ### Versicolor

# %%
versicolor_df = final_df[final_df["target"] == 1]
versicolor_df.loc[:, 'iris_type'] = "versicolor"
versicolor_df[:5]
# Out:
# /tmp/ipykernel_3926/1785623950.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   versicolor_df.loc[:, 'iris_type'] = "versicolor"
#     sepal_length  sepal_width  petal_length  petal_width  target   iris_type
# 50           7.0          3.2           4.7          1.4       1  versicolor
# 51           6.4          3.2           4.5          1.5       1  versicolor
# 52           6.9          3.1           4.9          1.5       1  versicolor
# 53           5.5          2.3           4.0          1.3       1  versicolor
# 54           6.5          2.8           4.6          1.5       1  versicolor

# %% [markdown]
# ### Virginica

# %%
virginica_df = final_df[final_df["target"] == 2]
virginica_df.loc[:, 'iris_type'] = "virginica"
virginica_df[:5]
# Out:
# /tmp/ipykernel_3926/420260184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   virginica_df.loc[:, 'iris_type'] = "virginica"
#      sepal_length  sepal_width  petal_length  petal_width  target  iris_type
# 100           6.3          3.3           6.0          2.5       2  virginica
# 101           5.8          2.7           5.1          1.9       2  virginica
# 102           7.1          3.0           5.9          2.1       2  virginica
# 103           6.3          2.9           5.6          1.8       2  virginica
# 104           6.5          3.0           5.8          2.2       2  virginica

# %%
final_df = pd.concat([setosa_df, versicolor_df, virginica_df])
final_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  target  iris_type
# 0             5.1          3.5           1.4          0.2       0     setosa
# 1             4.9          3.0           1.4          0.2       0     setosa
# 2             4.7          3.2           1.3          0.2       0     setosa
# 3             4.6          3.1           1.5          0.2       0     setosa
# 4             5.0          3.6           1.4          0.2       0     setosa
# ..            ...          ...           ...          ...     ...        ...
# 145           6.7          3.0           5.2          2.3       2  virginica
# 146           6.3          2.5           5.0          1.9       2  virginica
# 147           6.5          3.0           5.2          2.0       2  virginica
# 148           6.2          3.4           5.4          2.3       2  virginica
# 149           5.9          3.0           5.1          1.8       2  virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# # Plots

# %% [markdown]
# ### Sepal Length vs Sepal Width

# %%
plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.scatter(setosa_df["sepal_length"], setosa_df["sepal_width"], marker="+")
plt.scatter(versicolor_df["sepal_length"], versicolor_df["sepal_width"], marker="x")
plt.scatter(virginica_df["sepal_length"], virginica_df["sepal_width"], marker=".")
plt.legend(
    iris.target_names
)

# %% [markdown]
# # KNN Classifier

# %% [markdown]
# ## Import the Libaries

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Split the Dataset

# %%
X = final_df.drop(['target', 'iris_type'], axis='columns')
y = final_df.iris_type
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

# %% [markdown]
# ## Build the Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %% [markdown]
# ### Accuracy with 2 neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.9

# %% [markdown]
# ### Accuracy with 30 neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=30)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# ### Accuracy with 10 neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# ## Classify flowers using their Measurements

# %% [markdown]
# #### Mystery Flower 1

# %% [markdown]
# <img src="versicolor.png" width=150 height=150 id="versicolor">

# %% [markdown]
# **sepal_length** = 6.4
# **sepal_width** = 3.5
# **petal_length** = 4.5
# **petal_width** = 1.2

# %% [markdown]
# #### Mystery Flower 2

# %% [markdown]
# <img src="virginica.png" width="150" height="150" id="viriginica">

# %% [markdown]
# **sepal_length** = 5.9
# **sepal_width** = 3.0
# **petal_length** = 5.0
# **petal_width** = 1.8

# %% [markdown]
# #### Mystery Flower 3

# %% [markdown]
# <img src="setosa.png" width="150" height="150" id="setosa">

# %% [markdown]
# **sepal_length** = 5.1
# **sepal_width** = 3.5
# **petal_length** = 1.4
# **petal_width** = 0.2

# %%
### Find the type 
print("--- Enter sepal_length, sepal_width, petal_length and petal_wdith of Iris and we will tell you its type! ---")
print("--- Setosa vs Virginica vs Versicolor ---")

sepal_length = input("sepal_length: ")
sepal_width = input("sepal_width: ")
petal_length = input("petal_length: ")
petal_width = input("petal_width: ")

input_df = pd.DataFrame(
    {
        "sepal_length": [sepal_length],
        "sepal_width": [sepal_width],
        "petal_length": [petal_length],
        "petal_width": [petal_width]
    }
)
print("\nInput: ")
print(input_df)
type = knn.predict(input_df)
print(f"\nIris Type: {type}!!!!")
# Out:
# --- Enter sepal_length, sepal_width, petal_length and petal_wdith of Iris and we will tell you its type! ---
# --- Setosa vs Virginica vs Versicolor ---
#
# Input:
#   sepal_length sepal_width petal_length petal_width
# 0          6.4         3.5          4.5         1.2
#
# Iris Type: ['versicolor']!!!!

# %% [markdown]
# ## How good is our model?

# %%
from sklearn.metrics import confusion_matrix
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 8,  0,  0],
#        [ 0, 11,  0],
#        [ 0,  0, 11]])

# %%
import seaborn as sb
plt.figure(figsize=(7,5))
sb.heatmap(cm, annot=True)
plt.xlabel("Predicted Flower")
plt.ylabel("Real Flower")
# Out:
# Text(58.222222222222214, 0.5, 'Real Flower')
